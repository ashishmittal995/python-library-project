# %%
import pandas as pd
import numpy as nd
import matplotlib 
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
import plotly.express as px

# %%
✵WORKFLOW STAGES✵
Importing The Libraries
Loading & Reading The DataFrame
Meta Information Of The DataFrame
Segregating The Numerical & Categorical Columns
How Many Uniques Values Do We Have In EacH Columns?
Finding The Missig Values
Finding The Duplicate Records
Basics Statistics
Analysis The Customer Sentiments After The Telcom Market Survey
9.1. Timestamp
9.2. Q1.Which region of India are you from
9.3. Q2.Which type of location do you live in?
9.4. Q3.Which tech are you currently using?
9.5. Q4.Can you send an email with no attachments and just paragraphs of text instantly?
9.6. Q5.Are one-on-one video calls a smooth experience?
9.7. Q6.Do you experience delays in video conference calls?
9.8. Q7.How long does it take you to download a song of 4 minutes?
9.9. Q8.How much data do you use each month?
9.10. Q9.What do you usually do with your phone? (Multiple choices)
9.11. Q10.What do you think about the call drop rate?
9.12. Q11.Which network are you likely to recommend to a tourist who is in town for a few days?
9.13. Q12.Which network do you use more often?
9.14. Q13-VI.Why do you use your current network?
9.15. Q14-VI.How much are you paying for your mobile bill & WiFi services per month currently?
9.16. Q15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?
9.17. Q16-VI.Rate the service quality
9.18. Q13-Jio.Why do you use your current network?
9.19. Q14-Jio.How much are you paying for your mobile bill & WiFi services per month currently?
9.20. Q15-Jio.If VI lowers its price for services to the same level as Jio, will you switch to VI?
9.21. Q16-Jio.Rate the service quality
9.22. Q13-Airtel.Why do you use your current network?
9.23. Q14-Airtel.How much are you paying for your mobile bill & WiFi services per month currently?
9.20. Q15-Airtel.If VI lowers its price for services to the same level as Airtel, will you switch to VI?
9.21. Q16-Airtel.If VI provides higher quality services with a higher price as compared to Airtel, will you switch to VI?
9.22. Q17-Airtel.Rate the service quality
9.23. Q18.How much support do you think these companies are obtaining from the government?
9.22. Q19.Do you think the telecommunications market in India is tilting towards a monopoly?

# %%
df=pd.read_csv("Indian telecommunications market (1).csv")
df
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
# find first 5 enteries in the dataset
df=pd.read_csv("Indian telecommunications market (1).csv")
df.head()
# Out:
#              Timestamp 1.Which region of India are you from?  \
# 0  10/28/2021 18:56:57                                  West
# 1  10/28/2021 19:14:06                                 North
# 2  10/28/2021 21:30:05                                  West
# 3  10/28/2021 23:06:31                                  East
# 4   10/29/2021 6:35:21                                  West
#
#   2.Which type of location do you live in?  \
# 0                                    Urban
# 1                                    Urban
# 2                                    Urban
# 3                                    Urban
# 4                                    Urban
#
#   3.Which tech are you currently using?  \
# 0                                    4G
# 1                                    4G
# 2                                    4G
# 3                                    4G
# 4                                    4G
#
# ...

# %%
# to find the no. of rows and columns
df.shape
# Out:
# (50, 28)

# %%
# to find the no.of rows
df.shape[0]
# Out:
# 50

# %%
# to find the no. of columns
df.shape[1]
# Out:
# 28

# %%
# to find the name of each columns
df.columns
# Out:
# Index(['Timestamp', '1.Which region of India are you from?',
#        '2.Which type of location do you live in?',
#        '3.Which tech are you currently using?',
#        '4.Can you send an email with no attachments and just paragraphs of text instantly?',
#        '5.Are one-on-one video calls a smooth experience?',
#        '6.Do you experience delays in video conference calls?',
#        '7.How long does it take you to download a song of 4 minutes?',
#        '8.How much data do you use each month?',
#        '9.What do you usually do with your phone? (Multiple choices)',
#        '10.What do you think about the call drop rate? ',
#        '11.Which network are you likely to recommend to a tourist who is in town for a few days?',
#        '12.Which network do you use more often?',
#        '13-VI.Why do you use your current network?',
#        '14-VI.How much are you paying for your mobile bill & WiFi services per month currently?',
# ...

# %%
# to find the datatype of features
df.dtypes
# Out:
# Timestamp                                                                                                              object
# 1.Which region of India are you from?                                                                                  object
# 2.Which type of location do you live in?                                                                               object
# 3.Which tech are you currently using?                                                                                  object
# 4.Can you send an email with no attachments and just paragraphs of text instantly?                                     object
# 5.Are one-on-one video calls a smooth experience?                                                                      object
# 6.Do you experience delays in video conference calls?                                                                  object
# ...

# %%
# to find the information of feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 28 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   Timestamp                                                                                                           50 non-null     object
#  1   1.Which region of India are you from?                                                                               50 non-null     object
#  2   2.Which type of location do you live in?                                                                            50 non-null     object
#  3   3.Which tech are you currently using?                                                                               50 non-null     object
# ...

# %%
# to find only numerical data by using describe function
df.describe()
# Out:
#        10.What do you think about the call drop rate?   \
# count                                        50.000000
# mean                                          6.960000
# std                                           2.415596
# min                                           1.000000
# 25%                                           5.250000
# 50%                                           8.000000
# 75%                                           9.000000
# max                                          10.000000
#
#        16-VI.Rate the service quality  16-Jio.Rate the service quality  \
# count                        10.00000                        18.000000
# mean                          6.50000                         8.055556
# std                           1.95789                         1.392088
# min                           3.00000                         5.000000
# 25%                           5.00000                         7.000000
# ...

# %%
# to find the values of  all column unique name 
dict={}
for i in df.columns:
 dict[i] =df[i].value_counts().shape[0]
pd.DataFrame(dict,index=['Unique']).T.style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_c9aa4_row0_col0{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_c9aa4_row1_col0,#T_c9aa4_row7_col0,#T_c9aa4_row8_col0,#T_c9aa4_row11_col0,#T_c9aa4_row17_col0{
#             background-color:  #1414ff;
#             color:  #f1f1f1;
#         }#T_c9aa4_row2_col0,#T_c9aa4_row12_col0,#T_c9aa4_row13_col0,#T_c9aa4_row15_col0,#T_c9aa4_row19_col0,#T_c9aa4_row21_col0,#T_c9aa4_row23_col0,#T_c9aa4_row24_col0{
#             background-color:  #0a0aff;
#             color:  #f1f1f1;
#         }#T_c9aa4_row3_col0,#T_c9aa4_row4_col0,#T_c9aa4_row5_col0,#T_c9aa4_row6_col0,#T_c9aa4_row14_col0,#T_c9aa4_row18_col0,#T_c9aa4_row22_col0,#T_c9aa4_row27_col0{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_c9aa4_row9_col0{
#             background-color:  #ffa2a2;
#             color:  #000000;
#         }#T_c9aa4_row10_col0{
#             background-color:  #5656ff;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# # missing values

# %%
# to fill the missing values
df.fillna(value=0)
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
# to fill the null values with the previous value
df.fillna(method='pad')
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
# to find the percentage of missing value
total = df.isnull().sum().sort_values(ascending = False)
Percentage = (df.isnull().sum()/df.isnull().count())*100
pd.concat([total, Percentage], axis=1, keys=['Total', 'Percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_13e6b_row0_col0,#T_13e6b_row0_col1,#T_13e6b_row1_col0,#T_13e6b_row1_col1,#T_13e6b_row2_col0,#T_13e6b_row2_col1,#T_13e6b_row3_col0,#T_13e6b_row3_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_13e6b_row4_col0,#T_13e6b_row4_col1,#T_13e6b_row5_col0,#T_13e6b_row5_col1,#T_13e6b_row6_col0,#T_13e6b_row6_col1,#T_13e6b_row7_col0,#T_13e6b_row7_col1{
#             background-color:  #ff6666;
#             color:  #000000;
#         }#T_13e6b_row8_col0,#T_13e6b_row8_col1,#T_13e6b_row9_col0,#T_13e6b_row9_col1,#T_13e6b_row10_col0,#T_13e6b_row10_col1,#T_13e6b_row11_col0,#T_13e6b_row11_col1,#T_13e6b_row12_col0,#T_13e6b_row12_col1{
#             background-color:  #ff9898;
#             color:  #000000;
# ...

# %%
# to find the duplicate value
df[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
# to describe the table
df.describe()
# Out:
#        10.What do you think about the call drop rate?   \
# count                                        50.000000
# mean                                          6.960000
# std                                           2.415596
# min                                           1.000000
# 25%                                           5.250000
# 50%                                           8.000000
# 75%                                           9.000000
# max                                          10.000000
#
#        16-VI.Rate the service quality  16-Jio.Rate the service quality  \
# count                        10.00000                        18.000000
# mean                          6.50000                         8.055556
# std                           1.95789                         1.392088
# min                           3.00000                         5.000000
# 25%                           5.00000                         7.000000
# ...

# %% [markdown]
# ## timestamp

# %%
df["Timestamp"].value_counts().plot(x='month',kind='bar',color='maroon',title='which month did this survey happen the most')
# Out:
# <AxesSubplot:title={'center':'which month did this survey happen the most'}>

# %%
 total=df['1.Which region of India are you from?'].value_counts()
percentage=(df['1.Which region of India are you from?'].value_counts()/df['1.Which region of India are you from?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_4a82b_row0_col0,#T_4a82b_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_4a82b_row1_col0,#T_4a82b_row1_col1{
#             background-color:  #ff7e7e;
#             color:  #000000;
#         }#T_4a82b_row2_col0,#T_4a82b_row2_col1{
#             background-color:  #4c4cff;
#             color:  #f1f1f1;
#         }#T_4a82b_row3_col0,#T_4a82b_row3_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_4a82b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a82b_level0_row0" class="row_heading level0 row0" >West</th>
#                         <td id="T_4a82b_row0_col0" class="data row0 col0" >23</td>
# ...

# %%
df['1.Which region of India are you from?'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
total=df['2.Which type of location do you live in?'].value_counts()
percentage=(df['2.Which type of location do you live in?'].value_counts()/df['2.Which type of location do you live in?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_1905b_row0_col0,#T_1905b_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_1905b_row1_col0,#T_1905b_row1_col1{
#             background-color:  #6060ff;
#             color:  #000000;
#         }#T_1905b_row2_col0,#T_1905b_row2_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_1905b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1905b_level0_row0" class="row_heading level0 row0" >Urban</th>
#                         <td id="T_1905b_row0_col0" class="data row0 col0" >36</td>
#                         <td id="T_1905b_row0_col1" class="data row0 col1" >72.000000</td>
#             </tr>
#             <tr>
# ...

# %%
df['2.Which type of location do you live in?'].value_counts().plot(kind='bar',color='red',title='Which type of location do you live in')
# Out:
# <AxesSubplot:title={'center':'Which type of location do you live in'}>

# %%
total=df['3.Which tech are you currently using?'].value_counts()
percentage=(df['3.Which tech are you currently using?'].value_counts()/df['3.Which tech are you currently using?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_73419_row0_col0,#T_73419_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_73419_row1_col0,#T_73419_row1_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_73419_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73419_level0_row0" class="row_heading level0 row0" >4G</th>
#                         <td id="T_73419_row0_col0" class="data row0 col0" >48</td>
#                         <td id="T_73419_row0_col1" class="data row0 col1" >96.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_73419_level0_row1" class="row_heading level0 row1" >3G</th>
# ...

# %%
df['3.Which tech are you currently using?'].value_counts().plot(kind='bar',color='yellow',title='Which tech are you currently using')
# Out:
# <AxesSubplot:title={'center':'Which tech are you currently using'}>

# %%
total=df['4.Can you send an email with no attachments and just paragraphs of text instantly?'].value_counts()
percentage=(df['4.Can you send an email with no attachments and just paragraphs of text instantly?'].value_counts()/df['4.Can you send an email with no attachments and just paragraphs of text instantly?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_d86bd_row0_col0,#T_d86bd_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_d86bd_row1_col0,#T_d86bd_row1_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_d86bd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d86bd_level0_row0" class="row_heading level0 row0" >Yes</th>
#                         <td id="T_d86bd_row0_col0" class="data row0 col0" >43</td>
#                         <td id="T_d86bd_row0_col1" class="data row0 col1" >86.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d86bd_level0_row1" class="row_heading level0 row1" >No</th>
# ...

# %%
df['4.Can you send an email with no attachments and just paragraphs of text instantly?'].value_counts().plot(kind='bar',color='green',title='Can you send an email with no attachments and just paragraphs of text instantly?')
# Out:
# <AxesSubplot:title={'center':'Can you send an email with no attachments and just paragraphs of text instantly?'}>

# %%
total=df['5.Are one-on-one video calls a smooth experience?'].value_counts()
percentage=(df['5.Are one-on-one video calls a smooth experience?'].value_counts()/df['5.Are one-on-one video calls a smooth experience?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_be225_row0_col0,#T_be225_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_be225_row1_col0,#T_be225_row1_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_be225_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be225_level0_row0" class="row_heading level0 row0" >Yes</th>
#                         <td id="T_be225_row0_col0" class="data row0 col0" >37</td>
#                         <td id="T_be225_row0_col1" class="data row0 col1" >74.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_be225_level0_row1" class="row_heading level0 row1" >No</th>
# ...

# %%
df['5.Are one-on-one video calls a smooth experience?'].value_counts().plot(kind='bar',color='brown',title='Are one-on-one video calls a smooth experience')
# Out:
# <AxesSubplot:title={'center':'Are one-on-one video calls a smooth experience'}>

# %%
total=df['6.Do you experience delays in video conference calls?'].value_counts()
percentage=(df['6.Do you experience delays in video conference calls?'].value_counts()/df['6.Do you experience delays in video conference calls?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_8aeb6_row0_col0,#T_8aeb6_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_8aeb6_row1_col0,#T_8aeb6_row1_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_8aeb6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8aeb6_level0_row0" class="row_heading level0 row0" >No</th>
#                         <td id="T_8aeb6_row0_col0" class="data row0 col0" >27</td>
#                         <td id="T_8aeb6_row0_col1" class="data row0 col1" >54.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8aeb6_level0_row1" class="row_heading level0 row1" >Yes</th>
# ...

# %%
df['6.Do you experience delays in video conference calls?'].value_counts().plot(kind='bar',color='pink',title='Do you experience delays in video conference calls')
# Out:
# <AxesSubplot:title={'center':'Do you experience delays in video conference calls'}>

# %%
total=df['7.How long does it take you to download a song of 4 minutes?'].value_counts()
percentage=(df['7.How long does it take you to download a song of 4 minutes?'].value_counts()/df['7.How long does it take you to download a song of 4 minutes?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_43b6f_row0_col0,#T_43b6f_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_43b6f_row1_col0,#T_43b6f_row1_col1{
#             background-color:  #ececff;
#             color:  #000000;
#         }#T_43b6f_row2_col0,#T_43b6f_row2_col1{
#             background-color:  #1212ff;
#             color:  #f1f1f1;
#         }#T_43b6f_row3_col0,#T_43b6f_row3_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_43b6f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43b6f_level0_row0" class="row_heading level0 row0" >Less than 1 min</th>
#                         <td id="T_43b6f_row0_col0" class="data row0 col0" >30</td>
# ...

# %%
df['7.How long does it take you to download a song of 4 minutes?'] = df['7.How long does it take you to download a song of 4 minutes?'].map(
{'Less than 1 min':'< 1 min', '1 min to 2 mins':'1-2 mins', '5 mins to 10 mins':'5-10 mins', '2 mins to 5 mins': '2-5 mins'})

# %%
df['7.How long does it take you to download a song of 4 minutes?'].value_counts().plot(kind='bar',color='black',title='time taken to download a song of 4 min')
# Out:
# <AxesSubplot:title={'center':'time taken to download a song of 4 min'}>

# %%
total=df['8.How much data do you use each month?'].value_counts()
percentage=(df['8.How much data do you use each month?'].value_counts()/df['8.How much data do you use each month?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_58778_row0_col0,#T_58778_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_58778_row1_col0,#T_58778_row1_col1{
#             background-color:  #ff1c1c;
#             color:  #f1f1f1;
#         }#T_58778_row2_col0,#T_58778_row2_col1{
#             background-color:  #5454ff;
#             color:  #f1f1f1;
#         }#T_58778_row3_col0,#T_58778_row3_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_58778_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58778_level0_row0" class="row_heading level0 row0" >10GB to 50GB</th>
#                         <td id="T_58778_row0_col0" class="data row0 col0" >21</td>
# ...

# %%
df['8.How much data do you use each month?'] = df['8.How much data do you use each month?'].map(
    {'1GB to 10GB': '1-10 GB', '10GB to 50GB': '10-50 GB', 'More than 50GB': '>50GB', '100MB to 1GB' : '100MB-1GB'})

# %%
df['8.How much data do you use each month?'].value_counts().plot(kind='bar',color='red',title='data usage in a month',width=0.50)
# Out:
# <AxesSubplot:title={'center':'data usage in a month'}>

# %%
total=df['9.What do you usually do with your phone? (Multiple choices)'].value_counts()
percentage=(df['9.What do you usually do with your phone? (Multiple choices)'].value_counts()/df['9.What do you usually do with your phone? (Multiple choices)'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_1f6e4_row0_col0,#T_1f6e4_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_1f6e4_row1_col0,#T_1f6e4_row1_col1,#T_1f6e4_row2_col0,#T_1f6e4_row2_col1{
#             background-color:  #fffefe;
#             color:  #000000;
#         }#T_1f6e4_row3_col0,#T_1f6e4_row3_col1,#T_1f6e4_row4_col0,#T_1f6e4_row4_col1,#T_1f6e4_row5_col0,#T_1f6e4_row5_col1,#T_1f6e4_row6_col0,#T_1f6e4_row6_col1,#T_1f6e4_row7_col0,#T_1f6e4_row7_col1,#T_1f6e4_row8_col0,#T_1f6e4_row8_col1,#T_1f6e4_row9_col0,#T_1f6e4_row9_col1,#T_1f6e4_row10_col0,#T_1f6e4_row10_col1{
#             background-color:  #8080ff;
#             color:  #000000;
# ...

# %%
df['9.What do you usually do with your phone? (Multiple choices)'].value_counts().plot(kind='bar',color='brown',title='What do you usually do with your phone? (Multiple choices)')
# Out:
# <AxesSubplot:title={'center':'What do you usually do with your phone? (Multiple choices)'}>

# %%
total=df['11.Which network are you likely to recommend to a tourist who is in town for a few days?'].value_counts()
percentage=(df['11.Which network are you likely to recommend to a tourist who is in town for a few days?'].value_counts()/df['11.Which network are you likely to recommend to a tourist who is in town for a few days?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_7a3c9_row0_col0,#T_7a3c9_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_7a3c9_row1_col0,#T_7a3c9_row1_col1{
#             background-color:  #ff1616;
#             color:  #f1f1f1;
#         }#T_7a3c9_row2_col0,#T_7a3c9_row2_col1{
#             background-color:  #1616ff;
#             color:  #f1f1f1;
#         }#T_7a3c9_row3_col0,#T_7a3c9_row3_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_7a3c9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a3c9_level0_row0" class="row_heading level0 row0" >Jio</th>
#                         <td id="T_7a3c9_row0_col0" class="data row0 col0" >24</td>
# ...

# %%
df['11.Which network are you likely to recommend to a tourist who is in town for a few days?'].value_counts().plot(kind='bar',color='orange',title='network recommendation for tourist')
# Out:
# <AxesSubplot:title={'center':'network recommendation for tourist'}>

# %%
total=df['12.Which network do you use more often?'].value_counts()
percentage=(df['12.Which network do you use more often?'].value_counts()/df['12.Which network do you use more often?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_4f091_row0_col0,#T_4f091_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_4f091_row1_col0,#T_4f091_row1_col1{
#             background-color:  #ffaaaa;
#             color:  #000000;
#         }#T_4f091_row2_col0,#T_4f091_row2_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_4f091_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f091_level0_row0" class="row_heading level0 row0" >Airtel</th>
#                         <td id="T_4f091_row0_col0" class="data row0 col0" >22</td>
#                         <td id="T_4f091_row0_col1" class="data row0 col1" >44.000000</td>
#             </tr>
#             <tr>
# ...

# %%
df['12.Which network do you use more often?'].value_counts().plot(kind='bar',color='purple',title='Which network do you use more often?')
# Out:
# <AxesSubplot:title={'center':'Which network do you use more often?'}>

# %%
from IPython.display import YouTubeVideo
Video = YouTubeVideo("oRq4orh5fOo",width=500, height=350)
display(Video)

# %%
total=df['13-VI.Why do you use your current network?'].value_counts()
percentage=(df['13-VI.Why do you use your current network?'].value_counts()/df['13-VI.Why do you use your current network?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_2cb03_row0_col0,#T_2cb03_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_2cb03_row1_col0,#T_2cb03_row1_col1{
#             background-color:  #5454ff;
#             color:  #f1f1f1;
#         }#T_2cb03_row2_col0,#T_2cb03_row2_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_2cb03_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2cb03_level0_row0" class="row_heading level0 row0" >Others</th>
#                         <td id="T_2cb03_row0_col0" class="data row0 col0" >7</td>
#                         <td id="T_2cb03_row0_col1" class="data row0 col1" >70.000000</td>
#             </tr>
#             <tr>
# ...

# %%
df['13-VI.Why do you use your current network?'].value_counts().plot(kind='bar',color='grey',title='VI.Why do you use your current network?')
# Out:
# <AxesSubplot:title={'center':'VI.Why do you use your current network?'}>

# %%
total=df['14-VI.How much are you paying for your mobile bill & WiFi services per month currently?'].value_counts()
percentage=(df['14-VI.How much are you paying for your mobile bill & WiFi services per month currently?'].value_counts()/df['14-VI.How much are you paying for your mobile bill & WiFi services per month currently?'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_552bb_row0_col0,#T_552bb_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_552bb_row1_col0,#T_552bb_row1_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_552bb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_552bb_level0_row0" class="row_heading level0 row0" >Rs. 1000-3000</th>
#                         <td id="T_552bb_row0_col0" class="data row0 col0" >6</td>
#                         <td id="T_552bb_row0_col1" class="data row0 col1" >60.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_552bb_level0_row1" class="row_heading level0 row1" >Less than Rs. 1000</th>
# ...

# %%
df['14-VI.How much are you paying for your mobile bill & WiFi services per month currently?'].value_counts().plot(kind='bar',color='orange',title='How much are you paying for your mobile bill & WiFi services per month currently')
# Out:
# <AxesSubplot:title={'center':'How much are you paying for your mobile bill & WiFi services per month currently'}>

# %%
total=df['15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?'].value_counts()
percentage=df['15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?'].value_counts()/df['15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?'].count()
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_ba3f2_row0_col0,#T_ba3f2_row0_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_ba3f2_row1_col0,#T_ba3f2_row1_col1,#T_ba3f2_row2_col0,#T_ba3f2_row2_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_ba3f2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba3f2_level0_row0" class="row_heading level0 row0" >I will not switch</th>
#                         <td id="T_ba3f2_row0_col0" class="data row0 col0" >4</td>
#                         <td id="T_ba3f2_row0_col1" class="data row0 col1" >0.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_ba3f2_level0_row1" class="row_heading level0 row1" >I will switch to Jio</th>
# ...

# %%
df['15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?'].value_counts().plot(kind='bar',color='green',title='If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch')
# Out:
# <AxesSubplot:title={'center':'If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch'}>

# %%
total=df['16-VI.Rate the service quality'].value_counts()
percentage=(df['16-VI.Rate the service quality'].value_counts()/df['16-VI.Rate the service quality'].count())*100
pd.concat([total,percentage],axis=1,keys=['total','percentage']).style.background_gradient(cmap='bwr')
# Out:
# <style  type="text/css" >
# #T_8a8a1_row0_col0,#T_8a8a1_row0_col1,#T_8a8a1_row1_col0,#T_8a8a1_row1_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_8a8a1_row2_col0,#T_8a8a1_row2_col1{
#             background-color:  #fffefe;
#             color:  #000000;
#         }#T_8a8a1_row3_col0,#T_8a8a1_row3_col1,#T_8a8a1_row4_col0,#T_8a8a1_row4_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_8a8a1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total</th>        <th class="col_heading level0 col1" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8a8a1_level0_row0" class="row_heading level0 row0" >5.0</th>
#                         <td id="T_8a8a1_row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_8a8a1_row0_col1" class="data row0 col1" >30.000000</td>
# ...

# %%
df['16-VI.Rate the service quality'].value_counts().plot(kind='pie',title='Rate the service quality')
# Out:
# <AxesSubplot:title={'center':'Rate the service quality'}, ylabel='16-VI.Rate the service quality'>

# %%
df[ '19.Do you think the telecommunications market in India is tilting towards a monopoly?'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
